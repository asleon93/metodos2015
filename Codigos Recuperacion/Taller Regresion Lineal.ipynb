# %% [markdown]
# #Codigo :Taller de Regresion 17.1 a 17.6
# #del Capitulo 17 del Libro De Metodos Numericos para Ingenieros 5ed.
# Elaborado por: Alexander Suárez León-160003432

# %%
########################Clase para desarrollo de Regresiones Lineales#######################################
import math #para las operaciones matematicas
from matplotlib import pyplot as plt #para graficar
import numpy as np #para las matrices o vectores que se usen en el proceso

def sum_vect(xi):
    res=0
    for i in xi:
        res+=i
    return res
def sum_vect12(v1,v2):
     for i in range(n):
            p1+=xi[i]*yi[i]
    
def media(xi):
    n=float(len(xi))
    media=sum_vect(xi)/n
    return media

def varianza(xi):
    m=media(xi)
    var=0
    for i in xi:
        var+= (i-m)**2
    return var/(float(len(xi))-1)

def desv_es(xi):
    val=varianza(xi)
    return math.sqrt(val)

def coefvar(xi):
    m=media(xi)
    s=desv_es(xi)
    return 100*(s/m)

def a1(vectx,vecty):
    if len(vectx)==len(vecty):
        n=len(vectx)
        p1=0.0
        p2=0.0
        p3=0.0
        p4=0.0
        a1=0.0
        for i in range(n):
            p1+=xi[i]*yi[i]
            p2+=xi[i]
            p3+=yi[i]
            p4+=(xi[i])**2
            p5=p2**2
        a1=(n*p1-p2*p3)/(n*p4-p5)  ##Ecuacion a1=(nExiyi-ExiEyi)/(nExi²-(Exi)²)
    return a1


def a0(xi,yi):
    ym=media(yi)
    xm=media(xi)
    return ym-a1(xi,yi)*xm

def r(xi,yi):
    n=len(xi)
    ai1=a1(xi,yi)
    ai0=a0(xi,yi)
    y1=[]

    for i in range(n):
        r=ai0+ai1*xi[i]
        y1.append(r)
    return y1

#######################################################################################################
##Ejercicio 17.1
datos = [8.8,9.4,10,9.8,10.1,
         9.5,10.1,10.4,9.5,9.5,
         9.8,9.2,7.9,8.9,9.6,
         9.4,11.3,10.4,8.8,10.2,
         10,9.4,9.8,10.6,8.9]
print "\nEJERCICIO 17.1"
print "A.media:",media(datos)
print "B.desviacion estandar:",desv_es(datos)
print "C.varianza:",varianza(datos)
print "D.coeficiente de variacion:",coefvar(datos)
################################################3#Ejercicio 17.2
print "\nEjercicio 17.2 Histograma de los Datos"
rango = np.arange(7.5, 11.5 + 0.5, 0.5)
plt.title("Ejercicio 17.2 Histograma")
plt.hist(datos,rango)
plt.grid(True)
plt.show()
##################################################Ejercicio 17.3
datos1 = [28.65, 26.55, 26.65, 27.65, 27.35, 28.35, 26.85,
         28.65, 29.65, 27.85, 27.05, 28.25, 28.35, 26.75,
         27.65, 28.45, 28.65, 28.45, 31.65, 26.35, 27.75,
         29.25, 27.65, 28.65, 27.65, 28.55, 27.55, 27.25]
print "\nEJERCICIO 17.3"
print "A.media:",media(datos)
print "B.desviacion estandar:",desv_es(datos)
print "C.varianza:",varianza(datos)
print "D.coeficiente de variacion:",coefvar(datos)

rango1= np.arange(26,32+0.5,0.5)
plt.title("Ejercicio 17.3 Histograma")
plt.hist(datos1,rango1)
plt.grid(True)
plt.show()

###############################Ejercicio 17.4
print "\nEJERCICIO 17.4"
x = [0, 2, 4, 6, 9, 11, 12, 15, 17, 19]
y = [5, 6, 7, 6, 9, 8, 7, 10, 12, 12]
# Out:
# EJERCICIO 17.1
# A.media: 9.652
# B.desviacion estandar: 0.703041013503
# C.varianza: 0.494266666667
# D.coeficiente de variacion: 7.28388948925
# Ejercicio 17.2 Histograma de los Datos
# EJERCICIO 17.3
# A.media: 9.652
# B.desviacion estandar: 0.703041013503
# C.varianza: 0.494266666667
# D.coeficiente de variacion: 7.28388948925
